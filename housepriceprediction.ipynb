# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

# %%
house_price_dataframe = pd.read_csv('housingdata.csv')

# %%
house_price_dataframe.head()
# Out:
#       CRIM    ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
house_price_dataframe.rename(columns={'MEDV': 'price'}, inplace=True)

# %%
house_price_dataframe.head()
# Out:
#       CRIM    ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
house_price_dataframe.shape
# Out:
# (506, 14)

# %%
house_price_dataframe.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NX         0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# price      0
# dtype: int64

# %%
house_price_dataframe.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS          NX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT       price
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
correlation = house_price_dataframe.corr()

# %%
# constructing a heatmap to nderstand the correlation
plt.figure(figsize=(10,10))
sns.heatmap(correlation, cbar=True, square=True, fmt='.1f', annot=True, annot_kws={'size':8}, cmap='Blues')
# Out:
# <Axes: >

# %%
X = house_price_dataframe.drop(['price'], axis=1)
Y = house_price_dataframe['price']

# %%
print(X)
# Out:
#         CRIM    ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
print(Y)
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: price, Length: 506, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (506, 13) (404, 13) (102, 13)

# %%
model = RandomForestRegressor()

# %%
model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
training_data_prediction = model.predict(X_train)

# %%
print(training_data_prediction)
# Out:
# [23.515 20.824 21.504 34.473 14.826 14.66  22.057 15.195 12.443 22.134
#  14.467  7.175 28.733 46.465 34.25  20.676 22.368 19.436 33.022 20.082
#  26.108  8.634 44.675 21.883 23.428 19.626 19.923 25.707 22.562 32.201
#  19.491  8.985 18.032 21.563 13.104 10.428 12.215 23.842 19.84  15.09
#  24.186 27.608 15.285 17.308 15.92  13.727 25.449 16.833 49.022 17.87
#  21.397 32.413 16.966 23.065 19.502 19.165 22.374 36.346 29.945 32.914
#  21.668 47.447 14.027  6.275 19.334 10.653 26.888 18.825 20.998 46.187
#  39.724 34.217 20.952 35.02  24.85  49.061 13.094 18.454 19.662 22.705
#  46.708 23.737 25.204 22.042 44.413 17.745 31.295 35.166  8.137 20.383
#  18.543 12.644 24.728 48.597 35.768 22.011 37.62  17.946 15.378 28.5
#  21.794 19.661 17.768 19.135 19.625 21.655 20.699 33.296 21.843 13.104
#  19.25  20.933 17.541 19.845 46.03  15.98  16.19  18.573 14.463 32.649
#  14.716 44.103 34.532 20.004 14.673  9.101 11.547 12.946 18.933  7.917
#  22.95  11.826 20.141 47.464 22.153 19.908 31.833 20.936 32.605 31.71
#  14.092 16.164 49.29  20.637 16.343 13.107 49.118 31.6   11.452 19.301
#  27.942 32.097 22.603  9.217 24.217 23.867 22.351 13.138 27.775 33.203
#  14.469 19.282 26.724 35.282 29.493 23.046 10.804 23.461 23.066 35.514
#  23.419 20.118 19.391 10.702 22.197 19.089 20.396 10.773 41.747 47.59
#  13.549 20.314 24.194 16.366 21.767 22.102 33.141 20.953 24.839 19.05
#  31.579 14.35  14.675 22.819 23.371 18.128 25.902 27.103 27.284 21.626
#  18.648 27.858 14.29  20.912 17.956 41.405 27.619 20.657 25.391 18.6
#  17.754 19.037 23.768 25.661 16.656 13.997 21.747 21.634 10.302 18.998
#  21.475 19.484 18.808  9.047 23.241 20.311 15.772 23.407 29.847 21.471
#  14.427 20.035 30.302 21.408 46.633 17.728 31.396 48.143 16.888 17.609
#   9.798 20.249 16.673 15.666 16.276 19.493 29.634 28.346 19.195 21.695
#  24.527 10.446 25.772 46.067 21.182 23.06  20.204 13.122 18.63  15.937
#  14.116 22.713 15.221 20.908 26.562 17.806 23.455 14.509 21.489 20.179
#  25.833 27.241 23.486 18.965 23.243 24.913 15.041 19.354 24.412 16.905
#  24.197 30.852 16.748 24.638 16.253 13.683 11.885 24.302 14.946 38.419
#  19.881 42.891  9.012 23.033 14.523 15.209 17.527 22.843 22.39  46.578
#  18.758 30.095 25.286 18.365 25.771 11.407 41.603 20.465 16.969 25.145
#  15.389 24.407  7.931 23.869 18.751 21.634 23.631 23.594 17.512 18.355
#  13.95  26.373 14.151 22.085 20.334 14.806 16.81  22.714 24.572 21.806
#  23.039 30.511 21.42  20.26  28.353 23.417 13.175 23.816 12.183  8.079
#  20.689  9.983 47.166 25.116 12.611 17.233 14.187 27.914 19.261 21.181
#   8.85  21.111 22.038 19.944 23.694 25.173 27.417 14.007 16.674 20.666
#  18.758 24.432 14.451 25.807 33.086 26.987 24.614 18.709 20.159 13.838
#  23.526 13.674 22.922 21.733 21.241 17.975 11.902 32.689 19.482 49.083
#  22.7   23.533 20.952 18.866  8.512 21.046 23.317 21.268 17.346 26.724
#  20.95  27.722 14.555 47.867 30.862 24.721 21.966 17.842 31.201 15.512
#  22.842 20.99  20.217 22.993]

# %%
# R squared error
score_1 = metrics.r2_score(Y_train, training_data_prediction)

# Mean Absolute Error
score_2 = metrics.mean_absolute_error(Y_train, training_data_prediction)

print("R squared error : ", score_1)
print('Mean Absolute Error : ', score_2)
# Out:
# R squared error :  0.9815011193812193
# Mean Absolute Error :  0.848230198019801

# %%
plt.scatter(Y_train, training_data_prediction)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Price vs Preicted Price")
plt.show()

# %%
# accuracy for prediction on test data
test_data_prediction = model.predict(X_test)

# %%
# R squared error
score_1 = metrics.r2_score(Y_test, test_data_prediction)

# Mean Absolute Error
score_2 = metrics.mean_absolute_error(Y_test, test_data_prediction)

print("R squared error : ", score_1)
print('Mean Absolute Error : ', score_2)
# Out:
# R squared error :  0.8804957974119646
# Mean Absolute Error :  2.2079999999999993
